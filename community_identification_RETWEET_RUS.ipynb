# %%
import pandas as pd
from langcodes import *

test = pd.read_pickle('users_community_RETWEET_RUS.pkl')

# %%
def conv_language(lang):
    return Language.make(language=lang).display_name()

test['language'] = test['lang'].apply(conv_language)


lang_df = test[test['language'] != 'Unknown language']
hash_df = test.explode('hashtags').dropna(subset=['hashtags'])

for comm_id in sorted(test['community'].unique()):
    df_comm_lang = lang_df[lang_df['community'] == comm_id]
    top_langs = (
        df_comm_lang['language']
        .value_counts(normalize=True)
        .mul(100)
        .nlargest(5) 
    )
    
    df_comm_hash = hash_df[hash_df['community'] == comm_id]
    top_hash = (
        df_comm_hash['hashtags']
        .value_counts()
        .nlargest(5)
    )

    print(f"Community {comm_id}:")
    print("  Top 5 Languages:")
    for lang, pct in top_langs.items():
        print(f"    {lang}: {pct:.2f}%")
    
    print("  Top 5 Hashtags:")
    for tag, cnt in top_hash.items():
        print(f"    #{tag}: {cnt}")
    print()
# Out:
# Community 0:
#   Top 5 Languages:
#     English: 72.21%
#     Portuguese: 8.89%
#     Spanish: 5.59%
#     German: 3.35%
#     French: 1.82%
#   Top 5 Hashtags:
#     #WorldCup: 949248
#     #FRA: 115496
#     #CRO: 110233
#     #ENG: 107625
#     #BEL: 94883
#
# Community 1:
#   Top 5 Languages:
#     French: 80.23%
#     English: 12.81%
#     Spanish: 1.65%
#     Haitian Creole: 0.84%
#     Portuguese: 0.83%
#   Top 5 Hashtags:
#     #CM2018: 484112
#     #WorldCup: 149012
#     #FRA: 102068
#     #BEL: 30575
#     #SEN: 27795
#
# Community 2:
#   Top 5 Languages:
#     Arabic: 82.34%
#     English: 13.66%
#     French: 1.29%
#     Spanish: 1.04%
#     Italian: 0.25%
#   Top 5 Hashtags:
#     #WorldCup: 93467
#     #روسيا2018: 92173
#     #ARG: 26858
#     #FRA: 25702
#     #CRO: 22607
#
# Community 3:
#   Top 5 Languages:
#     Japanese: 80.35%
#     English: 15.32%
#     Spanish: 1.22%
#     German: 0.71%
#     French: 0.51%
#   Top 5 Hashtags:
#     #WorldCup: 201894
#     #JPN: 63904
#     #ワールドカップ: 57394
#     #daihyo: 54688
#     #日本代表: 35110
#
# Community 4:
#   Top 5 Languages:
#     English: 98.15%
#     Spanish: 0.26%
#     Slovenian: 0.24%
#     Romanian: 0.18%
#     Portuguese: 0.16%
#   Top 5 Hashtags:
#     #WorldCup: 3753
#     #ENG: 203
#     #ARG: 194
#     #FRA: 171
#     #CRO: 151
#
# Community 5:
#   Top 5 Languages:
#     English: 91.80%
#     French: 2.82%
#     Spanish: 1.13%
#     Indonesian: 0.65%
#     German: 0.36%
#   Top 5 Hashtags:
#     #WorldCup: 366613
#     #ENG: 124000
#     #ThreeLions: 49978
#     #worldcup: 42249
#     #FRA: 29232
#
# Community 6:
#   Top 5 Languages:
#     Portuguese: 65.10%
#     English: 23.40%
#     Spanish: 6.16%
#     French: 1.38%
#     Indonesian: 0.65%
#   Top 5 Hashtags:
#     #WorldCup: 58327
#     #POR: 8124
#     #FRA: 4579
#     #CRO: 4138
#     #BRA: 3232
#
# Community 7:
#   Top 5 Languages:
#     Turkish: 84.77%
#     English: 7.00%
#     Indonesian: 1.96%
#     French: 1.38%
#     Spanish: 0.91%
#   Top 5 Hashtags:
#     #WorldCup: 12312
#     #FRA: 2351
#     #CRO: 2115
#     #DünyaKupası: 1943
#     #ENG: 1758
#
# Community 8:
#   Top 5 Languages:
#     Spanish: 83.13%
#     English: 11.43%
#     Portuguese: 1.24%
#     Catalan: 0.86%
#     French: 0.75%
#   Top 5 Hashtags:
#     #Rusia2018: 506324
#     #WorldCup: 179437
#     #MEX: 149475
#     #FRA: 131212
#     #CRO: 123803
#
# Community 9:
#   Top 5 Languages:
#     English: 92.83%
#     Indonesian: 1.32%
#     Spanish: 1.13%
#     French: 0.75%
#     Portuguese: 0.55%
#   Top 5 Hashtags:
#     #WorldCup: 1089506
#     #FRA: 92817
#     #ENG: 89895
#     #BEL: 76315
#     #NGA: 66585
#
# Community 10:
#   Top 5 Languages:
#     Chinese: 99.90%
#     English: 0.10%
#   Top 5 Hashtags:
#     #泛亚: 7814
#     #BBC: 4889
#     #CNN: 4813
#     #China: 4244
#     #习近平: 3401
#
# Community 11:
#   Top 5 Languages:
#     Indonesian: 34.15%
#     English: 30.37%
#     Italian: 26.32%
#     Spanish: 3.07%
#     French: 0.95%
#   Top 5 Hashtags:
#     #WorldCup: 55434
#     #CRO: 5852
#     #FRA: 5441
#     #ENG: 5209
#     #Russia2018: 4722
#
# Community 12:
#   Top 5 Languages:
#     Thai: 50.38%
#     English: 41.71%
#     Spanish: 1.60%
#     French: 1.03%
#     Indonesian: 0.97%
#   Top 5 Hashtags:
#     #WorldCup: 102444
#     #สวัสดีบอลโลก: 47636
#     #ENG: 15341
#     #FRA: 12803
#     #GER: 12433
#
# Community 13:
#   Top 5 Languages:
#     Russian: 70.66%
#     English: 19.94%
#     Polish: 4.75%
#     Spanish: 1.11%
#     French: 0.71%
#   Top 5 Hashtags:
#     #ЧМ2018: 75536
#     #WorldCup: 52163
#     #чм2018: 14699
#     #самараживетфутболом: 12408
#     #worldcup: 11930
#
# Community 14:
#   Top 5 Languages:
#     Arabic: 97.40%
#     English: 2.39%
#     Spanish: 0.07%
#     Portuguese: 0.04%
#     Indonesian: 0.02%
#   Top 5 Hashtags:
#     #روسيا2018: 10450
#     #المنارة_للاستشارات: 1170
#     #WorldCup: 873
#     #السعودية: 763
#     #Conrad: 551
#
# Community 15:
#   Top 5 Languages:
#     English: 66.85%
#     Spanish: 28.67%
#     Indonesian: 0.96%
#     Korean: 0.57%
#     Polish: 0.50%
#   Top 5 Hashtags:
#     #WorldCup: 150669
#     #FIFAStadiumDJ: 121907
#     #PowerByEXO: 87691
#     #EXO: 75282
#     #엑소: 30020
#
# Community 16:
#   Top 5 Languages:
#     English: 96.95%
#     French: 0.68%
#     Spanish: 0.56%
#     Indonesian: 0.42%
#     Italian: 0.16%
#   Top 5 Hashtags:
#     #WorldCup: 50934
#     #ENG: 13285
#     #win: 9321
#     #WIN: 8015
#     #FRA: 6139
#
# Community 17:
#   Top 5 Languages:
#     Spanish: 96.67%
#     Portuguese: 1.21%
#     English: 0.84%
#     Lithuanian: 0.40%
#     Basque: 0.22%
#   Top 5 Hashtags:
#     #MaríaFraudes: 2514
#     #WorldCup: 9
#     #Rusia2018: 5
#     #BRA: 3
#     #MEX: 3
#
# Community 18:
#   Top 5 Languages:
#     English: 96.56%
#     Catalan: 1.88%
#     Portuguese: 0.39%
#     Tagalog: 0.33%
#     Spanish: 0.19%
#   Top 5 Hashtags:
#     #IPOB: 2019
#     #WhereIsNnamdiKanu: 1550
#     #WorldCup: 1382
#     #Referendum: 736
#     #HumanRights: 735
#
# Community 19:
#   Top 5 Languages:
#     Japanese: 95.07%
#     English: 4.82%
#     Tagalog: 0.03%
#     Indonesian: 0.02%
#     Basque: 0.02%
#   Top 5 Hashtags:
#     #NEWS: 33010
#     #BLUE: 32859
#     #WorldCup: 22589
#     #worldcup: 8294
#     #NowPlaying: 3975
#
# Community 20:
#   Top 5 Languages:
#     Arabic: 99.72%
#     English: 0.28%
#   Top 5 Hashtags:
#     #روسيا2018: 1272
#     #المانُياٌ_السويدُ: 1222
#     #كأٌس_العالمُ: 1119
#     #تونّس_بلجٍيكاُ: 66
#     #السعوديهُ_مصرُ: 31
