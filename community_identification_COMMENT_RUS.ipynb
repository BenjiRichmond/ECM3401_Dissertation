# %%
import pandas as pd
from langcodes import *

test = pd.read_pickle('users_community_COMMENT_RUS.pkl')

# %%
def conv_language(lang):
    return Language.make(language=lang).display_name()

test['language'] = test['lang'].apply(conv_language)


lang_df = test[test['language'] != 'Unknown language']
hash_df = test.explode('hashtags').dropna(subset=['hashtags'])

for comm_id in sorted(test['community'].unique()):
    df_comm_lang = lang_df[lang_df['community'] == comm_id]
    top_langs = (
        df_comm_lang['language']
        .value_counts(normalize=True)
        .mul(100)
        .nlargest(5) 
    )
    
    df_comm_hash = hash_df[hash_df['community'] == comm_id]
    top_hash = (
        df_comm_hash['hashtags']
        .value_counts()
        .nlargest(5)
    )

    print(f"Community {comm_id}:")
    print("  Top 5 Languages:")
    for lang, pct in top_langs.items():
        print(f"    {lang}: {pct:.2f}%")
    
    print("  Top 5 Hashtags:")
    for tag, cnt in top_hash.items():
        print(f"    #{tag}: {cnt}")
    print()
# Out:
# Community 0:
#   Top 5 Languages:
#     Spanish: 87.14%
#     English: 8.57%
#     Portuguese: 0.90%
#     Catalan: 0.78%
#     French: 0.72%
#   Top 5 Hashtags:
#     #Rusia2018: 48512
#     #MEX: 13895
#     #FRA: 12457
#     #CRO: 11583
#     #WorldCup: 10536
#
# Community 1:
#   Top 5 Languages:
#     French: 88.20%
#     English: 6.96%
#     Spanish: 0.99%
#     Danish: 0.97%
#     German: 0.48%
#   Top 5 Hashtags:
#     #CM2018: 34546
#     #WorldCup: 9908
#     #FRA: 8698
#     #cm2018: 5839
#     #FRACRO: 5366
#
# Community 2:
#   Top 5 Languages:
#     English: 81.09%
#     Spanish: 6.29%
#     German: 3.11%
#     Portuguese: 1.65%
#     Indonesian: 1.41%
#   Top 5 Hashtags:
#     #WorldCup: 142857
#     #ENG: 23315
#     #FRA: 19227
#     #CRO: 17349
#     #BEL: 15598
#
# Community 3:
#   Top 5 Languages:
#     Portuguese: 88.77%
#     Spanish: 4.85%
#     English: 2.31%
#     French: 0.90%
#     Italian: 0.57%
#   Top 5 Hashtags:
#     #AusênciaNasRadios: 2514
#     #AusênciaNasRádios: 637
#     #Ausêncianasradios: 30
#     #AusenciaNasRadios: 11
#     #BRA: 8
#
# Community 4:
#   Top 5 Languages:
#     Turkish: 90.08%
#     Indonesian: 4.05%
#     Spanish: 1.01%
#     English: 1.00%
#     Haitian Creole: 0.44%
#   Top 5 Hashtags:
#     #WorldCup: 2938
#     #mobilbahis: 1317
#     #Bets10kupa: 1080
#     #FRA: 976
#     #CRO: 833
#
# Community 5:
#   Top 5 Languages:
#     English: 92.86%
#     French: 1.85%
#     Spanish: 1.28%
#     Indonesian: 0.82%
#     Italian: 0.55%
#   Top 5 Hashtags:
#     #WorldCup: 31581
#     #FRA: 8517
#     #CRO: 7773
#     #ENG: 7207
#     #WinWithTecno: 6180
#
# Community 6:
#   Top 5 Languages:
#     Arabic: 96.02%
#     English: 3.72%
#     French: 0.10%
#     Portuguese: 0.03%
#     Spanish: 0.02%
#   Top 5 Hashtags:
#     #روسيا2018: 9990
#     #WorldCup: 9210
#     #كأس_العالم: 3554
#     #كاس_العالم: 2167
#     #كورة_روتانا: 2089
#
# Community 7:
#   Top 5 Languages:
#     English: 91.09%
#     Spanish: 1.81%
#     Indonesian: 1.48%
#     French: 0.68%
#     Portuguese: 0.63%
#   Top 5 Hashtags:
#     #WorldCup: 17191
#     #SABCKuzobalit: 1787
#     #KOLive: 1584
#     #ENG: 1343
#     #CRO: 1233
#
# Community 8:
#   Top 5 Languages:
#     English: 93.61%
#     Polish: 1.94%
#     German: 1.29%
#     Spanish: 0.69%
#     Indonesian: 0.38%
#   Top 5 Hashtags:
#     #WorldCup: 77241
#     #ENG: 21007
#     #worldcup: 9525
#     #CRO: 6532
#     #ThreeLions: 5921
#
# Community 9:
#   Top 5 Languages:
#     English: 49.38%
#     Spanish: 23.35%
#     French: 15.05%
#     Portuguese: 2.84%
#     Swedish: 1.31%
#   Top 5 Hashtags:
#     #WorldCup: 79626
#     #Rusia2018: 32854
#     #ENG: 19120
#     #FIFA: 18909
#     #Football: 18751
#
# Community 10:
#   Top 5 Languages:
#     English: 97.11%
#     Spanish: 0.69%
#     French: 0.56%
#     Indonesian: 0.48%
#     Estonian: 0.17%
#   Top 5 Hashtags:
#     #WorldCup: 25995
#     #ENG: 6982
#     #win: 4446
#     #WIN: 3349
#     #Win: 2036
#
# Community 11:
#   Top 5 Languages:
#     English: 82.07%
#     Chinese: 10.65%
#     Russian: 2.81%
#     Arabic: 0.69%
#     Spanish: 0.64%
#   Top 5 Hashtags:
#     #WorldCup: 20640
#     #泛亚: 2864
#     #BBC: 2228
#     #CNN: 2221
#     #Trump: 2145
#
# Community 12:
#   Top 5 Languages:
#     English: 96.69%
#     Dutch: 0.83%
#     Indonesian: 0.83%
#     Portuguese: 0.33%
#     French: 0.33%
#   Top 5 Hashtags:
#     #AWCup: 343
#     #WorldCup: 244
#     #ENG: 139
#     #BEL: 60
#     #CRO: 56
#
# Community 13:
#   Top 5 Languages:
#     Portuguese: 84.08%
#     Spanish: 7.35%
#     English: 5.85%
#     German: 0.48%
#     French: 0.35%
#   Top 5 Hashtags:
#     #Copa2018: 3021
#     #WorldCup: 2641
#     #JogaOQueSabe: 1596
#     #BRA: 1585
#     #FRA: 991
#
# Community 14:
#   Top 5 Languages:
#     Spanish: 83.36%
#     English: 8.94%
#     Italian: 1.61%
#     Portuguese: 1.25%
#     Catalan: 0.76%
#   Top 5 Hashtags:
#     #Rusia2018: 994
#     #ESP: 513
#     #FRA: 332
#     #CRO: 284
#     #RUS: 218
#
# Community 15:
#   Top 5 Languages:
#     English: 97.38%
#     Spanish: 1.61%
#     French: 0.20%
#     Indonesian: 0.20%
#     Danish: 0.20%
#   Top 5 Hashtags:
#     #WorldCup: 221
#     #Rusia2018: 167
#     #ENG: 123
#     #CRO: 80
#     #BEL: 76
#
# Community 16:
#   Top 5 Languages:
#     English: 92.12%
#     French: 1.68%
#     Spanish: 1.57%
#     Indonesian: 1.27%
#     German: 0.37%
#   Top 5 Hashtags:
#     #WorldCup: 5815
#     #YourSportsMemo: 1164
#     #NGA: 923
#     #FRA: 830
#     #SterlingBank: 827
#
# Community 17:
#   Top 5 Languages:
#     English: 99.83%
#     Indonesian: 0.17%
#   Top 5 Hashtags:
#     #WorldCup: 866
#     #ENG: 90
#     #England: 86
#     #FRA: 68
#     #France: 65
